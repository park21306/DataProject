# %% [markdown]
# <a href="https://colab.research.google.com/github/park21306/DataProject/blob/main/WordCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install wordcloud

# %%
pip install matplotlib

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = 'Kittisak (Park) Poonyanunt'

wordcloud = WordCloud(width = 800 , height = 400 , background_color = 'white').generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud , interpolation='bilinear')
plt.axis('off')
plt.show()
